# %% [markdown]
# # Telecome Churn Analysis

# %%
#import the required libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
telco_base_data = pd.read_csv(r"C:\Users\My PC\Downloads\Telechurn\Churn Website\data\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
telco_base_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telco_base_data.shape #rows,coulmn
# Out:
# (7043, 21)

# %%
telco_base_data.columns.values # what are columns in dataset
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Checking the data types of all the columns
telco_base_data.dtypes #datatypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Check the descriptive statistics of numeric variables
telco_base_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# #### SeniorCitizen is actually a categorical hence the 25%-50%-75% distribution is not propoer
#
# #### 75% customers have tenure less than 55 months
#
# #### Average Monthly charges are USD 64.76 whereas 25% customers pay more than USD 89.85 per month

# %%
telco_base_data['Churn'].value_counts().plot(kind='barh', figsize=(8, 6),color="orange") # select the column churn and count the values yes or No and plot the horizontal bar graph
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
100*telco_base_data['Churn'].value_counts()/len(telco_base_data['Churn']) # counts the number of values un the coulumns and then didvide by the length of column and mutilpy by 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
telco_base_data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# #### Data is highly imbalanced, ratio = 73:27
# #### so we analyse the data with other features while taking the target values separately to get some insights.

# %%
# Concise Summary of the dataframe, as we have too many columns, we are using the verbose = True mode
telco_base_data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
missing = pd.DataFrame((telco_base_data.isnull().sum())*100/telco_base_data.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index', y=0, data=missing,color="orange")
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# ## Missing Data - Initial Intuition
# ##### Here, we don't have any missing data.
# ##### General Thumb Rules:
#
# ##### For features with less missing values- can use regression to predict the missing values or fill with the mean of the values present, depending on the feature.
# ##### For features with very high number of missing values- it is better to drop those columns as they give very less insight on analysis.
# ##### As there's no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delete the columns, if you have more than 30-40% of missing values. But again there's a catch here, for example, Is_Car & Car_Type, People having no cars, will obviously have Car_Type as NaN (null), but that doesn't make this column useless, so decisions has to be taken wisely.

# %% [markdown]
# # Data Cleaning

# %%
telco_data = telco_base_data.copy()

# %%
telco_data.TotalCharges = pd.to_numeric(telco_data.TotalCharges, errors='coerce')
telco_data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
telco_data.loc[telco_data ['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# #### Missing Value Treatement
# ###### Since the % of these records compared to total dataset is very low ie 0.15%, it is safe to ignore them from further processing.

# %%
#Removing missing values 
telco_data.dropna(how = 'any', inplace = True) # "any" it will drop all the row is any one  value is missing ; "inplace=true" it modifies the dataframe and save changes without creating a new one,but it will default "false"

# telco_data.fillna(0)

# %% [markdown]
# ###### Divide customers into bins based on tenure e.g. for tenure < 12 months: assign a tenure group if 1-12, for tenure between 1 to 2 Yrs, tenure group of 13-24; so on...

# %%
# Get the max tenure
print(telco_data['tenure'].max())
# Out:
# 72

# %%
# Group the tenure in bins of 12 months
# Create a list of user-friendly string labels for each 12-month (1-year) tenure group.
# This list will look like: ['1 - 12', '13 - 24', '25 - 36', ...]
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]

telco_data['tenure_group'] = pd.cut(telco_data.tenure, range(1, 80, 12), right=False, labels=labels)
"""
Use the pandas 'cut' function to segment the numerical 'tenure' data into bins.
right=False: This specifies that the bins are left-inclusive but right-exclusive. This means a value of 12 months would fall into the '1 - 12' bin, but a value of 13 months would fall into the '13 - 24' bin.
"""
# Out:
# "\nUse the pandas 'cut' function to segment the numerical 'tenure' data into bins.\nright=False: This specifies that the bins are left-inclusive but right-exclusive. This means a value of 12 months would fall into the '1 - 12' bin, but a value of 13 months would fall into the '13 - 24' bin.\n"

# %%
telco_data['tenure_group'].value_counts() #selects the new coulum tenure group and  counts the occurence
# Out:
# tenure_group
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: count, dtype: int64

# %% [markdown]
#  ##### Remove columns not required for processing

# %%
#drop column customerID and tenure
telco_data.drop(columns= ['customerID','tenure'], axis=1, inplace=True) # axis=1: Specifies that you are dropping columns (axis=0 would mean rows).
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# # Data Exploration
# ###### **1. ** Plot distibution of individual predictors by churn
#  ### Univariate Analysis

# %%
#i=counter and predictor=column name
for i, predictor in enumerate(telco_data.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])): # churn-drop becuse it is target variable,total charge and monthly charge-continuous numerical variables,
    plt.figure(i)#creates a new empty plot.
    sns.countplot(data=telco_data, x=predictor, hue='Churn')
#countplot-This function from the seaborn library generates a count plot. 
#hue='Churn': This is the most important argument. It splits each bar into two segments based on the value of the Churn column ('Yes' or 'No').

# %%
telco_data['Churn'] = np.where(telco_data.Churn == 'Yes',1,0) # np.where is used to check the condition ,churn=="Yes" checks if the vallue in column is string ,if cndition is true=1 and false=0

# %%
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# #### Convert all the categorical variables into dummy variables

# %%
telco_data_dummies = pd.get_dummies(telco_data) #This function converts categorical variables (i.e., columns with text labels or objects)
# into a numerical format , for each coulm it creates a net se of column one for each unique category in that original column. The values in these new
# columns are binary (0 or 1).
telco_data_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0           True
# 1              0           56.95       1889.50      0          False
# 2              0           53.85        108.15      1          False
# 3              0           42.30       1840.75      0          False
# 4              0           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
sns.lmplot(data=telco_data_dummies, x='MonthlyCharges', y='TotalCharges', fit_reg=False) # fit reg is used to hide the regression line drawn default

# %% [markdown]
# #### Total Charges increase as Monthly Charges increase - as expected.

# %%
Mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[(telco_data_dummies["Churn"] == 0) ],
                color="Red", fill = True)
Mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[(telco_data_dummies["Churn"] == 1) ],
                ax =Mth, color="Blue", fill= True) # ax is used to plot both in same graph 
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# Text(0.5, 1.0, 'Monthly charges by churn')

# %% [markdown]
# ##### Insight: Churn is high when Monthly Charges ar high

# %%
Tot = sns.kdeplot(telco_data_dummies.TotalCharges[(telco_data_dummies["Churn"] == 0) ],
                color="Red", fill = True)
Tot = sns.kdeplot(telco_data_dummies.TotalCharges[(telco_data_dummies["Churn"] == 1) ],
                ax =Tot, color="Blue", fill= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# Text(0.5, 1.0, 'Total charges by churn')

# %% [markdown]
# ### **Surprising insight ** as higher Churn at lower Total Charges
#
# ###### However if we combine the insights of 3 parameters i.e. Tenure, Monthly Charges & Total Charges then the picture is bit clear :- Higher Monthly Charge at lower tenure results into lower Total Charge. Hence, all these 3 factors viz Higher Monthly Charge, Lower tenure and Lower Total Charge are linkd to High Churn.

# %%
plt.figure(figsize=(20,8))
telco_data_dummies.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ###### **Derived Insight: **
#
# ###### HIGH Churn seen in case of Month to month contracts, No online security, No Tech support, First year of subscription and Fibre Optics Internet
#
# ###### LOW Churn is seens in case of Long term contracts, Subscriptions without internet service and The customers engaged for 5+ years
#
# ###### Factors like Gender, Availability of PhoneService and # of multiple lines have alomost NO impact on Churn

# %% [markdown]
# #### This is also evident from the Heatmap below

# %%
plt.figure(figsize=(12,12))
sns.heatmap(telco_data_dummies.corr(), cmap="Paired")
# Out:
# <Axes: >

# %% [markdown]
# ### Bivariate Analysis

# %%
new_df1_target0=telco_data.loc[telco_data["Churn"]==0] # create a dataframe to slecet all rows where churn is 0 
new_df1_target1=telco_data.loc[telco_data["Churn"]==1] # create a dataframe to slecet all columns where churn is 1

# %%
def uniplot(df,col,title,hue=None):#defines a function named uniplot with four parameters
    
    sns.set_style('whitegrid')#white background
    sns.set_context('talk')#scaling of plot elements(like lables,lines)
    plt.rcParams["axes.labelsize"] = 20 #font size to 20
    plt.rcParams['axes.titlesize'] = 22 #font size to 22
    plt.rcParams['axes.titlepad'] = 30 #adjust spacing b/w plots
    
    
    temp = pd.Series(data = hue)#adds a tempory series from hue argument
    fig, ax = plt.subplots()#creates a fig and subplot
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())#dynamically calculates the width of the plot based on the number of unique values in the col and hue columns. The extra values (7 and 4) are likely used to ensure the plot is wide enough to prevent labels from overlapping.
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright') 
        
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define global blue & orange palette
blue_orange_palette = ["#1f77b4", "#ff7f0e"]  # matplotlib default blue & orange

# Your existing data filtering
new_df1_target0 = telco_data.loc[telco_data["Churn"] == 0]  # Non-churned customers
new_df1_target1 = telco_data.loc[telco_data["Churn"] == 1]  # Churned customers

def uniplot(df, col, title, hue=None):
    """
    Creates a count plot with proper formatting (blue & orange theme)
    """
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 16
    plt.rcParams['axes.titlesize'] = 18
    plt.rcParams['axes.titlepad'] = 20
    
    fig, ax = plt.subplots(figsize=(10, 6))
    
    if hue is not None:
        ax = sns.countplot(
            data=df, 
            x=col, 
            hue=hue, 
            order=df[col].value_counts().index,
            palette=blue_orange_palette
        )
    else:
        ax = sns.countplot(
            data=df, 
            x=col, 
            order=df[col].value_counts().index,
            color=blue_orange_palette[0]  # Always blue for single category
        )
    
    plt.xticks(rotation=45, ha='right')
    plt.title(title, pad=20)
    
    for container in ax.containers:
        ax.bar_label(container, fmt='%d')
    
    plt.tight_layout()
    plt.show()

print("=== CHURNED CUSTOMERS ANALYSIS ===")

uniplot(new_df1_target1, col='gender', title='Distribution of Gender for Churned Customers')
uniplot(new_df1_target1, col='Partner', title='Distribution of Partner Status for Churned Customers', hue='gender')
uniplot(new_df1_target1, col='PaymentMethod', title='Distribution of Payment Method for Churned Customers', hue='gender')
uniplot(new_df1_target1, col='Contract', title='Distribution of Contract Type for Churned Customers', hue='gender')
uniplot(new_df1_target1, col='TechSupport', title='Distribution of Tech Support for Churned Customers', hue='gender')
uniplot(new_df1_target1, col='SeniorCitizen', title='Distribution of Senior Citizen Status for Churned Customers', hue='gender')

print("\n=== NON-CHURNED CUSTOMERS ANALYSIS ===")
uniplot(new_df1_target0, col='Partner', title='Distribution of Partner Status for Non-Churned Customers', hue='gender')

def comparison_plot(df, col, title):
    """
    Creates side-by-side comparison of churned vs non-churned customers
    (blue & orange theme)
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    churned = df[df['Churn'] == 1]
    sns.countplot(data=churned, x=col, hue='gender', ax=ax1, palette=blue_orange_palette)
    ax1.set_title(f'{title} - Churned Customers')
    ax1.tick_params(axis='x', rotation=45)
    
    not_churned = df[df['Churn'] == 0]
    sns.countplot(data=not_churned, x=col, hue='gender', ax=ax2, palette=blue_orange_palette)
    ax2.set_title(f'{title} - Non-Churned Customers')
    ax2.tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()

# Example comparison plot
comparison_plot(telco_data, 'PaymentMethod', 'Payment Method Distribution')
# Out:
# === CHURNED CUSTOMERS ANALYSIS ===
# === NON-CHURNED CUSTOMERS ANALYSIS ===

# %% [markdown]
# ## CONCLUSION
# #### These are some of the quick insights from this exercise:
#
# #### Electronic check medium are the highest churners
# #### Contract Type - Monthly customers are more likely to churn because of no contract terms, as they are free to go customers.
# #### No Online security, No Tech Support category are high churners
# #### Non senior Citizens are high churners
# ###### Note: There could be many more such insights, so take this as an assignment and try to get more insights :)

# %%
telco_data_dummies.to_csv('tel_churn.csv')
